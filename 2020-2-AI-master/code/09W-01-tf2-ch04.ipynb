# %% [markdown]
# # 활성화 함수 tanh

# %%
# 그림 4.2 출력 코드
import math
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + math.exp(-x))

x = np.arange(-6, 6, 0.01)
sigmoid_x = [sigmoid(z) for z in x]
tanh_x = [math.tanh(z) for z in x]

plt.figure(figsize=(8, 6)) 

plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.plot(x, sigmoid_x, 'b-', label='sigmoid')
plt.plot(x, tanh_x, 'r--', label='tanh')
plt.legend()
plt.show()

# %% [markdown]
# # 인구증가율과 고령인구비율 회귀 분석

# %%
# 4.7 딥러닝 네트워크를 이용한 회귀
import tensorflow as tf
import numpy as np

# 인구증가율과 고령인구비율
X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=6, activation='tanh', input_shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.1), loss='mse')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 12
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4.8 딥러닝 네트워크의 학습
model.fit(X, Y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 2ms/step - loss: 254.2432
# Epoch 2/10
# 1/1 [==============================] - 0s 1ms/step - loss: 109.8856
# Epoch 3/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.7871
# Epoch 4/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6736
# Epoch 5/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6544
# Epoch 6/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6455
# Epoch 7/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6372
# Epoch 8/10
# 1/1 [==============================] - 0s 2ms/step - loss: 9.6283
# Epoch 9/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6184
# Epoch 10/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6074

# %%
# 4.9 딥러닝 네트워크의 Y값 예측
model.predict(X)
# Out:
# array([[15.96257 ],
#        [15.537596],
#        [15.804726],
#        [15.912355],
#        [15.87068 ],
#        [15.954603],
#        [15.825453],
#        [15.721996],
#        [15.544382],
#        [15.770369],
#        [15.488474],
#        [15.751654],
#        [15.813515],
#        [15.909792],
#        [15.551111],
#        [13.962172]], dtype=float32)

# %%
# 4.10 딥러닝 네트워크의 회귀선 확인
import matplotlib.pyplot as plt

line_x = np.arange(min(X), max(X), 0.01)
line_y = model.predict(line_x)

plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')

plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Population Rate (%)')
plt.show()

# %%
# 4.7 딥러닝 네트워크를 이용한 회귀
import tensorflow as tf
import numpy as np

# 인구증가율과 고령인구비율
X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=6, activation='tanh', input_shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.1), loss='mse')

model.summary()

# 4.8 딥러닝 네트워크의 학습
model.fit(X, Y, epochs=10)

# 4.9 딥러닝 네트워크의 Y값 예측
model.predict(X)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 12
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1/1 [==============================] - 0s 2ms/step - loss: 254.1015
# Epoch 2/10
# 1/1 [==============================] - 0s 1ms/step - loss: 100.1714
# Epoch 3/10
# 1/1 [==============================] - 0s 1ms/step - loss: 10.8179
# Epoch 4/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6819
# Epoch 5/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.4919
# Epoch 6/10
# 1/1 [==============================] - 0s 2ms/step - loss: 9.4138
# Epoch 7/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.3517
# Epoch 8/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.2913
# Epoch 9/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.2299
# Epoch 10/10
# 1/1 [==============================] - 0s 1ms/step - loss: 9.1678
# array([[16.084541],
#        [15.408185],
#        [15.132452],
#        [16.127302],
#        [15.332332],
#        [16.104782],
#        [16.036201],
#        [15.841615],
#        [15.42491 ],
#        [15.939906],
#        [15.286924],
#        [15.903128],
#        [16.017105],
#        [16.126417],
#        [15.441473],
#        [13.714149]], dtype=float32)

# %% [markdown]
# ## 인구증가율과 고령인구비율 회귀 분석
# * 텐서플로만을 이용한 회귀 분석

# %%
# 4.4 텐서플로를 이용해서 회귀선 구하기
import tensorflow as tf
import numpy as np
# import random

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

# a와 b를 랜덤한 값으로 초기화합니다.
# a = tf.Variable(random.random())
# b = tf.Variable(random.random())
a = tf.Variable(tf.random.uniform([1], 0, 1))
b = tf.Variable(tf.random.uniform([1], 0, 1))

# 잔차의 제곱의 평균을 반환하는 함수입니다.
def compute_loss():
    y_pred = a * X + b
    loss = tf.reduce_mean((Y - y_pred) ** 2)
    return loss

optimizer = tf.keras.optimizers.Adam(lr=0.07)
for i in range(1000):
    # 잔차의 제곱의 평균을 최소화(minimize)합니다.
    optimizer.minimize(compute_loss, var_list=[a, b])
    
    if i % 100 == 99:
        print(i, 'a:', a.numpy(), 'b:', b.numpy(), 'loss:', compute_loss().numpy())
# Out:
# 99 a: [0.10384322] b: [7.0220366] loss: 84.38282
# 199 a: [-0.1313938] b: [11.447518] loss: 27.56305
# 299 a: [-0.26537243] b: [13.967599] loss: 12.669933
# 399 a: [-0.32615837] b: [15.111071] loss: 10.091721
# 499 a: [-0.34795016] b: [15.521007] loss: 9.802749
# 599 a: [-0.35414627] b: [15.637564] loss: 9.78181
# 699 a: [-0.35554507] b: [15.663885] loss: 9.780832
# 799 a: [-0.35579532] b: [15.668588] loss: 9.780804
# 899 a: [-0.3558299] b: [15.669241] loss: 9.780803
# 999 a: [-0.35583317] b: [15.669303] loss: 9.780804

# %%
import matplotlib.pyplot as plt

line_x = np.arange(min(X), max(X), 0.01)
line_y = a * line_x + b

# 그래프를 그립니다.
plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')
plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Population Rate (%)')
plt.show()

# %% [markdown]
# # 보스턴 주택 가격 데이터세트(Boston Housing Dataset)

# %%
# 활성화 함수
import math
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

x = np.arange(-5, 5, 0.01)
sigmoid_x = [sigmoid(z) for z in x]
tanh_x = [math.tanh(z) for z in x]
relu = [0 if z < 0 else z for z in x]

plt.figure(figsize=(8, 6)) 

plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.plot(x, sigmoid_x, 'b-', label='sigmoid')
plt.plot(x, tanh_x, 'r--', label='tanh')
plt.plot(x, relu, 'g.', label='relu')
plt.legend()
plt.show()

# %%
# 4.11 데이터 불러오기
from tensorflow.keras.datasets import boston_housing
(train_X, train_Y), (test_X, test_Y) = boston_housing.load_data()

print(train_X.shape, test_X.shape)
print(train_X[0])
print(train_Y[0])
# Out:
# (404, 13) (102, 13)
# [  1.23247   0.        8.14      0.        0.538     6.142    91.7
#    3.9769    4.      307.       21.      396.9      18.72   ]
# 15.2

# %%
# 4.12 데이터 전처리(정규화)
x_mean = train_X.mean(axis=0)
x_std = train_X.std(axis=0)
train_X -= x_mean
train_X /= x_std
test_X -= x_mean
test_X /= x_std

y_mean = train_Y.mean(axis=0)
y_std = train_Y.std(axis=0)
train_Y -= y_mean
train_Y /= y_std
test_Y -= y_mean
test_Y /= y_std

print(train_X[0])
print(train_Y[0])
# Out:
# [-0.27224633 -0.48361547 -0.43576161 -0.25683275 -0.1652266  -0.1764426
#   0.81306188  0.1166983  -0.62624905 -0.59517003  1.14850044  0.44807713
#   0.8252202 ]
# -0.7821526033779157

# %%
# 4.13 Boston Housing Dataset 회귀 모델 생성
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=52, activation='relu', input_shape=(13,)),
    tf.keras.layers.Dense(units=39, activation='relu'),
    tf.keras.layers.Dense(units=26, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.07), loss='mse')

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 52)                728
# _________________________________________________________________
# dense_13 (Dense)             (None, 39)                2067
# _________________________________________________________________
# dense_14 (Dense)             (None, 26)                1040
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 27
# =================================================================
# Total params: 3,862
# Trainable params: 3,862
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4.14 회귀 모델 학습
history = model.fit(train_X, train_Y, epochs=25, batch_size=32, validation_split=0.25)
# Out:
# Epoch 1/25
# 10/10 [==============================] - 0s 13ms/step - loss: 1.8861 - val_loss: 1.0559
# Epoch 2/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4920 - val_loss: 0.5592
# Epoch 3/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3340 - val_loss: 0.4409
# Epoch 4/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2319 - val_loss: 0.2128
# Epoch 5/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1906 - val_loss: 0.2505
# Epoch 6/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1887 - val_loss: 0.2830
# Epoch 7/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2786 - val_loss: 0.5417
# Epoch 8/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3023 - val_loss: 0.2672
# Epoch 9/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2112 - val_loss: 0.2250
# Epoch 10/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1942 - val_loss: 0.1902
# Epoch 11/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1628 - val_loss: 0.1413
# Epoch 12/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1260 - val_loss: 0.1977
# Epoch 13/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1699 - val_loss: 0.3521
# Epoch 14/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1421 - val_loss: 0.2173
# Epoch 15/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1243 - val_loss: 0.1692
# Epoch 16/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1087 - val_loss: 0.1575
# Epoch 17/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2130 - val_loss: 0.1866
# Epoch 18/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1782 - val_loss: 0.1573
# Epoch 19/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1154 - val_loss: 0.2081
# Epoch 20/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1055 - val_loss: 0.2708
# Epoch 21/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1240 - val_loss: 0.1357
# Epoch 22/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1089 - val_loss: 0.1863
# Epoch 23/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0913 - val_loss: 0.1620
# Epoch 24/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0848 - val_loss: 0.1317
# Epoch 25/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0949 - val_loss: 0.1423

# %%
# 4.15 회귀 모델 학습 결과 시각화
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# 4.16 회귀 모델 평가
model.evaluate(test_X, test_Y)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2824
# 0.28240180015563965

# %%
# 4.17 실제 주택 가격과 예측 주택 가격 시각화
import matplotlib.pyplot as plt

pred_Y = model.predict(test_X)

plt.figure(figsize=(8,8))
plt.plot(test_Y, pred_Y, 'b.')
plt.axis([min(test_Y), max(test_Y), min(test_Y), max(test_Y)])

# y=x에 해당하는 대각선
plt.plot([min(test_Y), max(test_Y)], [min(test_Y), max(test_Y)], ls="--", c=".5")
plt.xlabel('test_Y')
plt.ylabel('pred_Y')

plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 33 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f208dc51620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# 4.18 모델 재정의 및 학습
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=52, activation='relu', input_shape=(13,)),
    tf.keras.layers.Dense(units=39, activation='relu'),
    tf.keras.layers.Dense(units=26, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.07), loss='mse')

history = model.fit(train_X, train_Y, epochs=25, batch_size=32, validation_split=0.25,
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience=3, monitor='val_loss')])
# Out:
# Epoch 1/25
# 10/10 [==============================] - 0s 13ms/step - loss: 1.6732 - val_loss: 0.5265
# Epoch 2/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4808 - val_loss: 0.4831
# Epoch 3/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3657 - val_loss: 0.4280
# Epoch 4/25
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2458 - val_loss: 0.2736
# Epoch 5/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2029 - val_loss: 0.2096
# Epoch 6/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1884 - val_loss: 0.2218
# Epoch 7/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1771 - val_loss: 0.1596
# Epoch 8/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1278 - val_loss: 0.1483
# Epoch 9/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2240 - val_loss: 0.3552
# Epoch 10/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1916 - val_loss: 0.2158
# Epoch 11/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1530 - val_loss: 0.2890

# %%
# 4.19 회귀 모델 학습 결과 시각화
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# 4.20 회귀 모델 평가
model.evaluate(test_X, test_Y)
# Out:
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2904
# 0.29041820764541626

# %%
# 4.21 실제 주택 가격과 예측 주택 가격 시각화
import matplotlib.pyplot as plt

pred_Y = model.predict(test_X)

plt.figure(figsize=(8,8))
plt.plot(test_Y, pred_Y, 'b.')
plt.axis([min(test_Y), max(test_Y), min(test_Y), max(test_Y)])

plt.plot([min(test_Y), max(test_Y)], [min(test_Y), max(test_Y)], ls="--", c=".3")
plt.xlabel('test_Y')
plt.ylabel('pred_Y')

plt.show()

# %%
# 모델 재정의 및 학습, dropout 사용
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=52, activation='relu', input_shape=(13,)),
    tf.keras.layers.Dropout(.1),
    tf.keras.layers.Dense(units=39, activation='relu'),
    tf.keras.layers.Dense(units=26, activation='relu'),
    tf.keras.layers.Dropout(.1),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.07), loss='mse')

history = model.fit(train_X, train_Y, epochs=25, batch_size=32, validation_split=0.25,
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience=4, monitor='val_loss')])
# Out:
# Epoch 1/25
# 10/10 [==============================] - 0s 11ms/step - loss: 2.0774 - val_loss: 0.9725
# Epoch 2/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4948 - val_loss: 0.5337
# Epoch 3/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4091 - val_loss: 0.2935
# Epoch 4/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3512 - val_loss: 0.6088
# Epoch 5/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4219 - val_loss: 0.3731
# Epoch 6/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3301 - val_loss: 0.6404
# Epoch 7/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4108 - val_loss: 0.3534

# %%
# 4.19 회귀 모델 학습 결과 시각화
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# 4.20 회귀 모델 평가
model.evaluate(test_X, test_Y)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5132
# 0.5132124423980713

# %%
# 4.21 실제 주택 가격과 예측 주택 가격 시각화
import matplotlib.pyplot as plt

pred_Y = model.predict(test_X)

plt.figure(figsize=(8,8))
plt.plot(test_Y, pred_Y, 'b.')
plt.axis([min(test_Y), max(test_Y), min(test_Y), max(test_Y)])

plt.plot([min(test_Y), max(test_Y)], [min(test_Y), max(test_Y)], ls="--", c=".3")
plt.xlabel('test_Y')
plt.ylabel('pred_Y')

plt.show()
